# %%
print ("Hi")
# Out:
# Hi

# %%
from google.cloud import bigquery

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
client = bigquery.Client(project = 'sn-1992')

# %%
from pandas.io import gbq

# %%
df = gbq.read_gbq('Select author from Test_Data_03_28.comments_copy', project_id = 'sn-1992')
# Out:
# Requesting query... ok.
# Job ID: job_YsG90O0rCmNrsBwkKi9zgJhwDw3D
# Query running...
#   Elapsed 10.71 s. Waiting...
#   Elapsed 21.12 s. Waiting...
# Query done.
# Processed: 77.4 MB
# Standard price: $0.00 USD
#
# Retrieving results...
#   Got page: 1; 1% done. Elapsed 23.89 s.
#   Got page: 2; 2% done. Elapsed 25.72 s.
#   Got page: 3; 4% done. Elapsed 28.22 s.
#   Got page: 4; 5% done. Elapsed 30.35 s.
#   Got page: 5; 6% done. Elapsed 32.26 s.
#   Got page: 6; 7% done. Elapsed 34.33 s.
#   Got page: 7; 8% done. Elapsed 36.53 s.
#   Got page: 8; 10% done. Elapsed 38.51 s.
#   Got page: 9; 11% done. Elapsed 40.61 s.
#   Got page: 10; 12% done. Elapsed 42.75 s.
#   Got page: 11; 13% done. Elapsed 45.5 s.
#   Got page: 12; 14% done. Elapsed 47.82 s.
#   Got page: 13; 15% done. Elapsed 50.19 s.
#   Got page: 14; 17% done. Elapsed 53.25 s.
#   Got page: 15; 18% done. Elapsed 55.31 s.
#   Got page: 16; 19% done. Elapsed 57.52 s.
#   Got page: 17; 20% done. Elapsed 59.62 s.
# ...

# %%
df.describe()
# Out:
#          author
# count   8171681
# unique   236359
# top     tptacek
# freq      33839

# %%
df
# Out:
#              author
# 0          masklinn
# 1          masklinn
# 2          masklinn
# 3          masklinn
# 4          masklinn
# 5          masklinn
# 6          masklinn
# 7          masklinn
# 8          masklinn
# 9          masklinn
# 10         masklinn
# 11         masklinn
# 12         masklinn
# 13         masklinn
# 14         masklinn
# 15         masklinn
# 16         masklinn
# 17         masklinn
# 18         masklinn
# 19         masklinn
# 20         masklinn
# 21         masklinn
# 22         masklinn
# 23         masklinn
# 24         masklinn
# 25         masklinn
# 26         masklinn
# 27         masklinn
# 28         masklinn
# 29         masklinn
# ...             ...
# 8399387  tlrobinson
# 8399388  tnorthcutt
# 8399389  todayiamme
# 8399390  tokenadult
# 8399391  tokenadult
# 8399392  tokenadult
# 8399393  tokenadult
# 8399394  tonyhburns
# 8399395  touristtam
# 8399396  triviatise
# 8399397  tseabrooks
# 8399398  turbojerry
# 8399399  turingbook
# ...
